# %% [markdown]
# <a href="https://colab.research.google.com/github/Premrufus/BharatIntenRepo/blob/main/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA SCIENCE INTERN - BHARAT INTERN**

# %% [markdown]
# # **TASK 1 - Stock Prediction**

# %% [markdown]
# ### **Problem Statement:** To predict Stock Price of a Company using LSTM

# %% [markdown]
# #### **About Dataset**
#
# The Google stock dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
#
# The columns in the dataset are as follows:
#
# * Symbol: The name of the company, which is GOOG in this case.
# * Date: The year and date of the stock data.
# * Close: The closing price of Google's stock on a particular day.
# * High: The highest value reached by Google's stock on the given day.
# * Low: The lowest value reached by Google's stock on the given day.
# * Open: The opening value of Google's stock on the given day.
# * Volume: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
# * adjClose: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
# * adjHigh: The adjusted highest value reached by Google's stock on the given day.
# * adjLow: The adjusted lowest value reached by Google's stock on the given day.
# * adjOpen: The adjusted opening value of Google's stock on the given day.
# * adjVolume: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
# * divCash: The amount of cash dividend paid out to shareholders on the given day.
# * splitFactor: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.
#
# This dataset can be used for a variety of purposes, such as:
#
# * Analyzing the historical performance of Google's stock.
# * Building predictive models to forecast Google's future stock prices.
# * Developing trading strategies to profit from the movement of Google's stock prices.
#
# The dataset is available in CSV format and can be downloaded from [Kaggle](https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction/).

# %% [markdown]
# ### **Importing Libraries and Dataset to be used**

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Google Stocks.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ### **Gathering Insights**

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ### **Data Pre-processing**

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ### **Creating LSTM Model**

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 108ms/step - loss: 0.0071 - mean_absolute_error: 0.0606 - val_loss: 0.0169 - val_mean_absolute_error: 0.1045
# Epoch 2/100
# 28/28 [==============================] - 1s 53ms/step - loss: 8.6853e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0074 - val_mean_absolute_error: 0.0678
# Epoch 3/100
# 28/28 [==============================] - 1s 53ms/step - loss: 4.3962e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0052 - val_mean_absolute_error: 0.0562
# Epoch 4/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.0847e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0041 - val_mean_absolute_error: 0.0485
# Epoch 5/100
# 28/28 [==============================] - 2s 59ms/step - loss: 4.2207e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0049 - val_mean_absolute_error: 0.0542
# Epoch 6/100
# 28/28 [==============================] - 2s 83ms/step - loss: 4.1090e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0054 - val_mean_absolute_error: 0.0575
# Epoch 7/100
# 28/28 [==============================] - 2s 86ms/step - loss: 3.7722e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0048 - val_mean_absolute_error: 0.0537
# Epoch 8/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.8559e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0049 - val_mean_absolute_error: 0.0548
# Epoch 9/100
# 28/28 [==============================] - 3s 107ms/step - loss: 3.5721e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0042 - val_mean_absolute_error: 0.0498
# Epoch 10/100
# 28/28 [==============================] - 2s 81ms/step - loss: 3.6375e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0048 - val_mean_absolute_error: 0.0543
# Epoch 11/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.6151e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0054 - val_mean_absolute_error: 0.0596
# Epoch 12/100
# 28/28 [==============================] - 3s 123ms/step - loss: 3.6255e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0042 - val_mean_absolute_error: 0.0505
# Epoch 13/100
# 28/28 [==============================] - 3s 97ms/step - loss: 3.3351e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0044 - val_mean_absolute_error: 0.0527
# Epoch 14/100
# 28/28 [==============================] - 3s 93ms/step - loss: 3.3856e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0057 - val_mean_absolute_error: 0.0618
# Epoch 15/100
# 28/28 [==============================] - 2s 85ms/step - loss: 3.2153e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0037 - val_mean_absolute_error: 0.0479
# Epoch 16/100
# 28/28 [==============================] - 2s 84ms/step - loss: 3.2474e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0063 - val_mean_absolute_error: 0.0660
# Epoch 17/100
# 28/28 [==============================] - 2s 77ms/step - loss: 3.6940e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0023 - val_mean_absolute_error: 0.0358
# Epoch 18/100
# 28/28 [==============================] - 3s 123ms/step - loss: 3.0811e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0036 - val_mean_absolute_error: 0.0464
# Epoch 19/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.1697e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0058 - val_mean_absolute_error: 0.0621
# Epoch 20/100
# 28/28 [==============================] - 2s 77ms/step - loss: 3.7269e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0037 - val_mean_absolute_error: 0.0475
# Epoch 21/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.2448e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0044 - val_mean_absolute_error: 0.0530
# Epoch 22/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.7636e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0038 - val_mean_absolute_error: 0.0483
# Epoch 23/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.8553e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0042 - val_mean_absolute_error: 0.0514
# Epoch 24/100
# 28/28 [==============================] - 5s 173ms/step - loss: 2.6103e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0057 - val_mean_absolute_error: 0.0620
# Epoch 25/100
# 28/28 [==============================] - 3s 110ms/step - loss: 3.0876e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0027 - val_mean_absolute_error: 0.0390
# Epoch 26/100
# 28/28 [==============================] - 3s 116ms/step - loss: 2.8044e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0034 - val_mean_absolute_error: 0.0455
# Epoch 27/100
# 28/28 [==============================] - 3s 111ms/step - loss: 2.4918e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0044 - val_mean_absolute_error: 0.0531
# Epoch 28/100
# 28/28 [==============================] - 3s 100ms/step - loss: 2.5898e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0049 - val_mean_absolute_error: 0.0562
# Epoch 29/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.5297e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0045 - val_mean_absolute_error: 0.0532
# Epoch 30/100
# 28/28 [==============================] - 1s 54ms/step - loss: 2.4424e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0035 - val_mean_absolute_error: 0.0452
# Epoch 31/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3970e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0037 - val_mean_absolute_error: 0.0468
# Epoch 32/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.5488e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0034 - val_mean_absolute_error: 0.0453
# Epoch 33/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.3268e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0036 - val_mean_absolute_error: 0.0461
# Epoch 34/100
# 28/28 [==============================] - 3s 90ms/step - loss: 2.4903e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271
# Epoch 35/100
# 28/28 [==============================] - 3s 118ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 36/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.3330e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 37/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3493e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 38/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.2700e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0044 - val_mean_absolute_error: 0.0539
# Epoch 39/100
# 28/28 [==============================] - 3s 110ms/step - loss: 2.3387e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0051 - val_mean_absolute_error: 0.0579
# Epoch 40/100
# 28/28 [==============================] - 5s 165ms/step - loss: 2.2346e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0019 - val_mean_absolute_error: 0.0321
# Epoch 41/100
# 28/28 [==============================] - 3s 113ms/step - loss: 2.1268e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0025 - val_mean_absolute_error: 0.0376
# Epoch 42/100
# 28/28 [==============================] - 3s 110ms/step - loss: 2.1086e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 43/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.9940e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275
# Epoch 44/100
# 28/28 [==============================] - 3s 122ms/step - loss: 2.0808e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0043 - val_mean_absolute_error: 0.0532
# Epoch 45/100
# 28/28 [==============================] - 3s 112ms/step - loss: 2.0495e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 46/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.9508e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0019 - val_mean_absolute_error: 0.0334
# Epoch 47/100
# 28/28 [==============================] - 3s 91ms/step - loss: 2.1550e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0022 - val_mean_absolute_error: 0.0364
# Epoch 48/100
# 28/28 [==============================] - 3s 93ms/step - loss: 2.1183e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0037 - val_mean_absolute_error: 0.0504
# Epoch 49/100
# 28/28 [==============================] - 3s 121ms/step - loss: 1.9310e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0023 - val_mean_absolute_error: 0.0359
# Epoch 50/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.9051e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
# Epoch 51/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.8038e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 52/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7848e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0259
# Epoch 53/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.7987e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 54/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.7737e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0033 - val_mean_absolute_error: 0.0463
# Epoch 55/100
# 28/28 [==============================] - 4s 125ms/step - loss: 1.8464e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 56/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.6386e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 57/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.7082e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0027 - val_mean_absolute_error: 0.0412
# Epoch 58/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.8443e-04 - mean_absolute_error: 0.0097 - val_loss: 9.4898e-04 - val_mean_absolute_error: 0.0225
# Epoch 59/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.0423e-04 - mean_absolute_error: 0.0103 - val_loss: 9.6271e-04 - val_mean_absolute_error: 0.0225
# Epoch 60/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8446e-04 - mean_absolute_error: 0.0099 - val_loss: 6.6327e-04 - val_mean_absolute_error: 0.0189
# Epoch 61/100
# 28/28 [==============================] - 3s 106ms/step - loss: 1.8569e-04 - mean_absolute_error: 0.0100 - val_loss: 8.5859e-04 - val_mean_absolute_error: 0.0214
# Epoch 62/100
# 28/28 [==============================] - 3s 89ms/step - loss: 1.7904e-04 - mean_absolute_error: 0.0098 - val_loss: 8.4858e-04 - val_mean_absolute_error: 0.0213
# Epoch 63/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.5489e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0026 - val_mean_absolute_error: 0.0408
# Epoch 64/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5464e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 65/100
# 28/28 [==============================] - 3s 107ms/step - loss: 1.5422e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 66/100
# 28/28 [==============================] - 3s 112ms/step - loss: 1.6889e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 67/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.5886e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 68/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.6267e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 69/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4366e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 70/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3641e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0019 - val_mean_absolute_error: 0.0335
# Epoch 71/100
# 28/28 [==============================] - 2s 86ms/step - loss: 1.4025e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 72/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.2938e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 73/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.3647e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 74/100
# 28/28 [==============================] - 3s 109ms/step - loss: 1.2955e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 75/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.3027e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 76/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3198e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 77/100
# 28/28 [==============================] - 3s 117ms/step - loss: 1.2527e-04 - mean_absolute_error: 0.0082 - val_loss: 8.4187e-04 - val_mean_absolute_error: 0.0212
# Epoch 78/100
# 28/28 [==============================] - 4s 148ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0028 - val_mean_absolute_error: 0.0440
# Epoch 79/100
# 28/28 [==============================] - 4s 123ms/step - loss: 1.2937e-04 - mean_absolute_error: 0.0082 - val_loss: 9.9537e-04 - val_mean_absolute_error: 0.0233
# Epoch 80/100
# 28/28 [==============================] - 2s 86ms/step - loss: 1.1880e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0010 - val_mean_absolute_error: 0.0235
# Epoch 81/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.2599e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 82/100
# 28/28 [==============================] - 2s 90ms/step - loss: 1.1656e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 83/100
# 28/28 [==============================] - 4s 157ms/step - loss: 1.2678e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 84/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1355e-04 - mean_absolute_error: 0.0078 - val_loss: 6.2653e-04 - val_mean_absolute_error: 0.0181
# Epoch 85/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.2197e-04 - mean_absolute_error: 0.0079 - val_loss: 5.6124e-04 - val_mean_absolute_error: 0.0171
# Epoch 86/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1406e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 87/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3183e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 88/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.0774e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 89/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.0162e-04 - mean_absolute_error: 0.0073 - val_loss: 4.8080e-04 - val_mean_absolute_error: 0.0160
# Epoch 90/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.1886e-04 - mean_absolute_error: 0.0077 - val_loss: 9.1055e-04 - val_mean_absolute_error: 0.0223
# Epoch 91/100
# 28/28 [==============================] - 3s 90ms/step - loss: 1.1811e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 92/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.1746e-04 - mean_absolute_error: 0.0076 - val_loss: 5.0266e-04 - val_mean_absolute_error: 0.0163
# Epoch 93/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.2640e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 94/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.3321e-04 - mean_absolute_error: 0.0082 - val_loss: 6.3548e-04 - val_mean_absolute_error: 0.0183
# Epoch 95/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.0631e-04 - mean_absolute_error: 0.0073 - val_loss: 6.1448e-04 - val_mean_absolute_error: 0.0179
# Epoch 96/100
# 28/28 [==============================] - 2s 55ms/step - loss: 9.3550e-05 - mean_absolute_error: 0.0068 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 97/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.0342e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 98/100
# 28/28 [==============================] - 3s 92ms/step - loss: 9.8662e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0032 - val_mean_absolute_error: 0.0472
# Epoch 99/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.2879e-04 - mean_absolute_error: 0.0084 - val_loss: 6.7538e-04 - val_mean_absolute_error: 0.0189
# Epoch 100/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1248e-04 - mean_absolute_error: 0.0075 - val_loss: 6.2508e-04 - val_mean_absolute_error: 0.0181

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 21ms/step
# array([[0.40628272, 0.40781495],
#        [0.40558338, 0.40726528],
#        [0.4026432 , 0.4043056 ],
#        [0.4080664 , 0.40933156],
#        [0.41144168, 0.4126533 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1424.2157, 1424.0797],
#        [1422.9192, 1423.061 ],
#        [1417.4683, 1417.5757],
#        [1427.5225, 1426.8906],
#        [1433.78  , 1433.0469]], dtype=float32)

# %% [markdown]
# ### **Visualizing Actual Vs Predicted Data**

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1424.215698      1424.079712
# 2020-05-28  1396.86  1416.73     1422.919189      1423.061035
# 2020-05-29  1416.94  1428.92     1417.468262      1417.575684
# 2020-06-01  1418.39  1431.82     1427.522461      1426.890625
# 2020-06-02  1430.55  1439.22     1433.780029      1433.046875

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ### **Predicting the Price for upcoming 10 days**

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2389.605713      2403.335938
# 2021-06-10  2494.01  2521.60     2394.841064      2409.458740
# 2021-06-11  2524.92  2513.93     2414.377441      2428.960693
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
#  <h1> <p align = "center"> ------------ THANK YOU --------------- </h1>
